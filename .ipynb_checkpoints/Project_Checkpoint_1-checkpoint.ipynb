# %%
#Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# %% [markdown]
# **Data Preprocessing**

# %%
#Open Dataset
ad_data = pd.read_csv('Dataset_Ads.csv')
# #Fill Nulls
# ad_data['gender'] = ad_data['gender'].fillna('Unknown')
# ad_data['browsing_history'] = ad_data['browsing_history'].fillna('Unknown')
# ad_data['time_of_day'] = ad_data['time_of_day'].fillna('Unknown')
# ad_data['device_type'] = ad_data['device_type'].fillna('Unknown')
# ad_data['ad_position'] = ad_data['ad_position'].fillna('Unknown')
# ad_data = ad_data.drop('id', axis=1)
# ad_data = ad_data.drop('full_name', axis=1)
# ad_data_nonulls = ad_data.dropna()
# ad_data_nonulls.head()
ad_data
# Out:
#       Age  Gender    Income  Location Ad Type    Ad Topic   Ad Placement  \
# 0      61    Male  35717.43     Urban  Banner      Travel   Social Media
# 1      41    Male  47453.25     Rural   Video      Travel  Search Engine
# 2      49  Female  68126.35     Rural    Text        Food   Social Media
# 3      68  Female  64585.73  Suburban    Text      Health        Website
# 4      63    Male  21109.40     Urban  Native     Fashion  Search Engine
# ...   ...     ...       ...       ...     ...         ...            ...
# 9995    7    Male  69925.29     Rural    Text     Fashion   Social Media
# 9996   35    Male  42182.75     Urban  Native  Technology        Website
# 9997   42    Male  55084.12  Suburban    Text     Finance  Search Engine
# 9998   34    Male  39382.80     Rural  Native  Technology   Social Media
# 9999   54  Female  66441.59  Suburban  Banner  Technology  Search Engine
#
#       Clicks                  Click Time  Conversion Rate     CTR
# ...

# %%
#Encode Categorical Values
encoder = LabelEncoder()
ad_data_encoded = ad_data_nonulls.copy()
ad_data_encoded['gender'] = encoder.fit_transform(ad_data_encoded['gender'])
ad_data_encoded['device_type'] = encoder.fit_transform(ad_data_encoded['device_type'])
ad_data_encoded['ad_position'] = encoder.fit_transform(ad_data_encoded['ad_position'])
ad_data_encoded['browsing_history'] = encoder.fit_transform(ad_data_encoded['browsing_history'])
ad_data_encoded['time_of_day'] = encoder.fit_transform(ad_data_encoded['time_of_day'])

#Decouple Features and Target
ad_data_resetindex = ad_data_encoded.reset_index().drop('index',axis=1)
ad_features = ad_data_resetindex.drop('click',axis=1)
ad_target = ad_data_resetindex['click']

#Scale Features
standard_scale = StandardScaler()
standard_scale.fit(ad_features)
standardized_ad_features = standard_scale.fit_transform(ad_features)

# %%
#Visualize Class Imbalance
plt.figure(figsize=(6, 6))
sns.countplot(x='click', data=pd.DataFrame(ad_target, columns=['click']), hue='click') 
plt.show()

# %%
#SMOTE
smote = SMOTE()
ad_x_smote, ad_y_smote = smote.fit_resample(standardized_ad_features, ad_target)

# %%
#Visualize Classes After Smote
plt.figure(figsize=(6, 6))
sns.countplot(x='click', data=pd.DataFrame(ad_y_smote, columns=['click']), hue='click') 
plt.show()

# %%
#Split Data
x_train, x_test, y_train, y_test = train_test_split(ad_x_smote, ad_y_smote, train_size=.8, random_state=8000)

# %% [markdown]
# **Test Implementation of Sklearn Classifier to check dataset viability - DELETE LATER**

# %%
#Decision Tree Classifier Training
decision_tree = DecisionTreeClassifier(criterion='entropy')
decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#Decision Tree Testing and Accuracy
decision_tree_predictions = decision_tree.predict(x_test)
dt_accuracy = accuracy_score(y_test, decision_tree_predictions)
dt_precision = precision_score(y_test, decision_tree_predictions, average='weighted')
dt_recall = recall_score(y_test, decision_tree_predictions, average='weighted')
dt_f1 = f1_score(y_test, decision_tree_predictions, average='weighted')
print(dt_accuracy)
print(dt_precision)
print(dt_recall)
print(dt_f1)
# Out:
# 0.8225205070842655
# 0.8252514566099384
# 0.8225205070842655
# 0.8222299588799467
